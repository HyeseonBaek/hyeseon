# %%
class Point:
    def show(self,n,m):
        print("(%s,%s)" %(n,m))
        
a = Point(1,2)
a.show()

b = Point(3,4)
b.show()

a = a+b
a.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-fb207ceee894> in <module>
#       3         print("(%s,%s)" %(n,m))
#       4
# ----> 5 a = Point(1,2)
#       6 a.show()
#       7
#
# TypeError: Point() takes no arguments

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
for row in data:
# Out:
#   File "<ipython-input-66-cb866ae7643e>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
#실습문제 3번

s1 = input("암호화 합니다. 입력하세요 : ")
s2 = s1.split()
s2.reverse()
s2
# Out:
# 암호화 합니다. 입력하세요 : 2 e f
# ['f', 'e', '2']

# %%
#실습문제 4번

def inputData():
    for  i in range(1,11):
        
            name = input("이름을 입력하세요 : ")
            telnum = input("전화번호를 입력하세요 : ")
            contact[name] = telnum
def searchData():
    while True:
        name = input("검색할 이름을 입력하세요 : ")
        telnum = input(name,"의 전화번호는  : ",contact[name])
contact = {}

while True:
    inputData()
    searchData()

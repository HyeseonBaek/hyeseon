# %%
#실습문제 1번

x = int(input("x값을 입력하세요: "))
print("입력받은 x값으로 계산한 y = 3x^2 + 5x + 3 의 y값은",3*x**2+5*x+3)
# Out:
# x값을 입력하세요: 2
# 입력받은 x값으로 계산한 y = 3x^2 + 5x + 3 의 y값은 25

# %%
#실습문제 2번

pi = 3.14
r = float(input("반지름을 입력하세요: "))
print("입력받은 반지름으로 계산한 원의 둘레는",pi*2*r)
print("입력받은 반지름으로 계산한 원의 넓이는",pi*r**2)
# Out:
# 반지름을 입력하세요: 3
# 입력받은 반지름으로 계산한 원의 둘레는 18.84
# 입력받은 반지름으로 계산한 원의 넓이는 28.26
